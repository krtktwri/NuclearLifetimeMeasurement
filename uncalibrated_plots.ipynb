# %%
from modules.utils import *

# %%
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams.update({'font.size': 15})

# %%
plt.title('Na-22 Spectrum [Left Detector]')
plot_MCA('left_Na_1')
plt.show()

# %%
plt.title('Na-22 Spectrum [Right Detector]')
plot_MCA('right_Na_1')
plt.show()

# %%
plt.title('Post Gain-Adjustment Na-22 Spectrum [Left Detector]')
plot_MCA('left_Na_2')
plt.show()

# %%
plt.title('Post Gain-Adjustment Na-22 Spectrum [Right Detector]')
plot_MCA('right_Na_2')
plt.show()

# %%
plt.title('Post SCA Adjustment Na-22 Spectrum [Left Detector]')
plot_MCA('left_Na_2_withSCAadjustment')
plt.show()

# %%
plt.title('Post SCA Adjustment Na-22 Spectrum [Right Detector]')
plot_MCA('right_Na_2_withSCAadjustment')
plt.show()

# %%
plt.title('Life Time Curve of Ba-133')
plot_MCA('Life_time_curve')
plt.show()

# %%
plt.title('Complete Ba-133 Spectrum')
plot_MCA('Ba_Full_Spectrum')
plt.show()

# %%
plt.title('Isolated Ba-133 81 KeV Peak')
plot_MCA('Ba_81KeV')
plt.show()

# %%
plt.title('Isolated Ba-133 356 KeV Peak')
plot_MCA('Ba_356KeV')
plt.show()

# %%
plt.title('TAC Calibration Peaks [with Na-22]')
plot_MCA('Na_TAC_Calibration')
plt.show()
